# %%
import torch
from wav2vec2.model import wav2vec2_model

# %%
ckpt_path = "./checkpoints/DPHuBERT-sp0.75.pth"
ckpt = torch.load(ckpt_path)

# %%
model = wav2vec2_model(**ckpt["config"])
result = model.load_state_dict(ckpt["state_dict"], strict=False)

print(f"missing: {result.missing_keys}, unexpected: {result.unexpected_keys}")
print(f"{sum(p.numel() for p in model.parameters())} params")
# Out:
# missing: [], unexpected: []
# 23585946 params

# %%
model
# Out:
# Wav2Vec2Model(
#   (feature_extractor): FeatureExtractor(
#     (conv_layers): ModuleList(
#       (0): ConvLayerBlock(
#         (layer_norm): GroupNorm(257, 257, eps=1e-05, affine=True)
#         (conv): Conv1d(1, 257, kernel_size=(10,), stride=(5,), bias=False)
#       )
#       (1): ConvLayerBlock(
#         (conv): Conv1d(257, 512, kernel_size=(3,), stride=(2,), bias=False)
#       )
#       (2): ConvLayerBlock(
#         (conv): Conv1d(512, 510, kernel_size=(3,), stride=(2,), bias=False)
#       )
#       (3): ConvLayerBlock(
#         (conv): Conv1d(510, 512, kernel_size=(3,), stride=(2,), bias=False)
#       )
#       (4): ConvLayerBlock(
#         (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#       )
#       (5): ConvLayerBlock(
#         (conv): Conv1d(512, 396, kernel_size=(2,), stride=(2,), bias=False)
#       )
#       (6): ConvLayerBlock(
#         (conv): Conv1d(396, 249, kernel_size=(2,), stride=(2,), bias=False)
#       )
#     )
#   )
#   (encoder): Encoder(
#     (feature_projection): FeatureProjection(
#       (layer_norm): LayerNorm((249,), eps=1e-05, elementwise_affine=True)
#       (projection): Linear(in_features=249, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (pos_conv_embed): ConvolutionalPositionalEmbedding(
#         (conv): Conv1d(768, 768, kernel_size=(128,), stride=(1,), padding=(64,), groups=16)
#       )
#       (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (layers): ModuleList(
#         (0): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=128, bias=True)
#             (v_proj): Linear(in_features=768, out_features=128, bias=True)
#             (q_proj): Linear(in_features=768, out_features=128, bias=True)
#             (out_proj): Linear(in_features=128, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=643, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=643, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=128, bias=True)
#             (v_proj): Linear(in_features=768, out_features=128, bias=True)
#             (q_proj): Linear(in_features=768, out_features=128, bias=True)
#             (out_proj): Linear(in_features=128, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=255, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=255, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=384, bias=True)
#             (v_proj): Linear(in_features=768, out_features=384, bias=True)
#             (q_proj): Linear(in_features=768, out_features=384, bias=True)
#             (out_proj): Linear(in_features=384, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=365, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=365, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=256, bias=True)
#             (v_proj): Linear(in_features=768, out_features=256, bias=True)
#             (q_proj): Linear(in_features=768, out_features=256, bias=True)
#             (out_proj): Linear(in_features=256, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=1062, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=1062, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=256, bias=True)
#             (v_proj): Linear(in_features=768, out_features=256, bias=True)
#             (q_proj): Linear(in_features=768, out_features=256, bias=True)
#             (out_proj): Linear(in_features=256, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=107, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=107, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=192, bias=True)
#             (v_proj): Linear(in_features=768, out_features=192, bias=True)
#             (q_proj): Linear(in_features=768, out_features=192, bias=True)
#             (out_proj): Linear(in_features=192, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=170, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=170, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=320, bias=True)
#             (v_proj): Linear(in_features=768, out_features=320, bias=True)
#             (q_proj): Linear(in_features=768, out_features=320, bias=True)
#             (out_proj): Linear(in_features=320, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=361, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=361, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=320, bias=True)
#             (v_proj): Linear(in_features=768, out_features=320, bias=True)
#             (q_proj): Linear(in_features=768, out_features=320, bias=True)
#             (out_proj): Linear(in_features=320, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=1405, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=1405, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): EncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): EncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=19, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=19, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): EncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=310, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=310, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): EncoderLayer(
#           (attention): SelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=320, bias=True)
#             (v_proj): Linear(in_features=768, out_features=320, bias=True)
#             (q_proj): Linear(in_features=768, out_features=320, bias=True)
#             (out_proj): Linear(in_features=320, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=626, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=626, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
# )
